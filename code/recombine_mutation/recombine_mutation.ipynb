# %% [markdown]
# Recombine mutation

# %%
# %load_ext autoreload
# %autoreload 2

from recombine_mutation import main
import random

# %%
N_RUNS = 1
random.seed(10)

best_variants, fitness_progressions = main(n_runs=N_RUNS)

print(best_variants)
# Out:
# c:\Users\Matouš\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# ISAG

# %%
N_RUNS = 160000 # 149361, number of start variant for single mutation walk benchmark
random.seed(10)

best_variants, fitness_progressions = main(n_runs=N_RUNS)

# %% [markdown]
# Save / Load results

# %%
import pickle
file_name = 'results_PhoQ_190.pkl'

# %%
with open(file_name, 'wb') as f:
    pickle.dump([best_variants, fitness_progressions], f)

# %%
with open(file_name, 'rb') as f:
    best_variants, fitness_progressions = pickle.load(f)

# %%
min_f = 10
for prog in fitness_progressions:
    if prog[-1] < min_f:
        min_f = prog[-1]
min_f
# Out:
# 0.042166666894

# %% [markdown]
# Plot learning curve

# %%
import matplotlib.pyplot as plt

# %%
run_idx = 2

n_evaluations = [i for i in range(1, len(fitness_progressions[run_idx])+1)]
plt.plot(n_evaluations, fitness_progressions[run_idx])
plt.xlabel('Number of Evaluations')
plt.ylabel('Highest Fitness Reached (relative to WT variant)')
finish = 'Final variant: ' + best_variants[run_idx] + ' ({:.2f})'.format(fitness_progressions[run_idx][-1])
plt.title('Recombine mutation - GB1\n' + finish)
plt.show()
